# %% [markdown]
# # matplotlib exercises

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Use matplotlib to plot the following equation:
#
#     - y=x^2−x+2
#
# You'll need to write the code that generates the x and y points.
# Add an anotation for the point 0, 0, the origin.

# %%
x = range(1, 101)
y = [n**2 - n + 2 for n in x]

plt.annotate('Origin', xy=(0, 0), xytext=(5, 2000),
             arrowprops={'facecolor': 'red'})

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
#     - y=√x
#     - y=x^3
#     - y=2^x
#     - y=1/(x+1)
#
# You can use functions from the math module to help implement some of the equations above.

# %%
x = range(1, 101)
y1 = [np.sqrt(n) for n in x]
plt.plot(x, y1, c = 'r')

# %%
y2 = [n**3 for n in x]
plt.plot(x, y2, c = 'orange')

# %%
y3 = [2**n for n in x]
plt.plot(x, y3, c='y')

# %%
y4 = [1/(n +1) for n in x]
plt.plot(x, y4, c = 'g')

# %% [markdown]
# ### 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x = range(1, 101)
y1 = [np.sqrt(n) for n in x]
y2 = [n**3 for n in x]
y3 = [2**n for n in x]
y4 = [1/(n +1) for n in x]


plt.suptitle('Combo Deal')

plt.subplot(221)
plt.plot(x, y1, c = 'r')

plt.subplot(222)
plt.plot(x, y2, c = 'orange')

plt.subplot(223)
plt.plot(x, y3, c = 'yellow')

plt.subplot(224)
plt.plot(x, y4, c = 'g')

plt.show()

# %% [markdown]
# ### 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x = range(1, 5)
y1 = [np.sqrt(n) for n in x]
y2 = [n**3 for n in x]
y3 = [2**n for n in x]
y4 = [1/(n +1) for n in x]
plt.plot(x, y1, c='g', label = '$y=\sqrt{x}$')
plt.plot(x, y2, c='red', label='$y=x^3$')
plt.plot(x, y3, c='gray', label='$y=2^x$')
plt.plot(x, y4, c='y', label='$y=1/(x+1)}$')

plt.title('Lines')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# Bonus Write the code necessary to write your name on a chart. Use box letters.

# %%
x = [2, 2.5, 2.75, 2.25, 2.75, 3] 
y = [1, 3, 2, 2, 2, 1]
x2 = [n + 1 for n in x]
x3 = [4, 4, 5, 5, 4, 5]
y3 = [1, 3, 3, 2, 2, 1]
x4 = [5.25, 5.25, 6.25, 6.25, 5.25]
y4 = [1, 3, 3, 1, 1]
x5 = [6.5, 6.5, 7.5, 7.5]
y5 = [1, 3, 1, 3] 

plt.plot(x, y, )
plt.plot(x2, y)
plt.plot(x3, y3)
plt.plot(x4, y4)
plt.plot(x5, y5)


plt.grid()

# %% [markdown]
# Bonus: use curves for letters in your name that have curves in them.
